# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
final_data = requests.get("https://github.com/djay/covidthailand").text

# %%
final_data_raw = BeautifulSoup(final_data, 'html')

# %%
type(final_data_raw)
# Out:
# bs4.BeautifulSoup

# %%
print(final_data_raw.prettify())
# Out:
# <!DOCTYPE html>
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-efd2f2257c96.css" media="all" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-6b1e37da2254.css" media="all" rel="stylesheet"/>
# ...

# %%
FinalDataTables = final_data_raw.find_all('table')
FinalDataTables
# Out:
# [<table aria-labelledby="folders-and-files" class="Box-sc-g0xbh4-0 cAQuiW"><thead class="Box-sc-g0xbh4-0 iiUlLN"><tr class="Box-sc-g0xbh4-0 jmggSN"><th class="Box-sc-g0xbh4-0 kvYunM" colspan="2"><span class="Text-sc-17v1xeu-0 gPDEWA text-bold">Name</span></th><th class="Box-sc-g0xbh4-0 hrLuxA" colspan="1"><span class="Text-sc-17v1xeu-0 gPDEWA text-bold">Name</span></th><th class="hide-sm"><div class="Truncate__StyledTruncate-sc-23o1d2-0 dliONX width-fit" title="Last commit message"><span class="Text-sc-17v1xeu-0 gPDEWA text-bold">Last commit message</span></div></th><th class="Box-sc-g0xbh4-0 cuEKae" colspan="1"><div class="Truncate__StyledTruncate-sc-23o1d2-0 dliONX width-fit" title="Last commit date"><span class="Text-sc-17v1xeu-0 gPDEWA text-bold">Last commit date</span></div></th></tr></thead><tbody><tr class="Box-sc-g0xbh4-0 jEbBOT"><td class="bgColor-muted p-1 rounded-top-2" colspan="3"><div class="Box-sc-g0xbh4-0 brJRqk"><h2 class="Heading__StyledHeading-sc-1c1dgg0-0 cgQnMS sr
# ...

# %%
type(FinalDataTables[0])
# Out:
# bs4.element.Tag

# %%
FinalTags = set()
for tag in final_data_raw.find_all():
    FinalTags.add(tag.name)
print(FinalTags)
# Out:
# {'path', 'query-builder', 'ol', 'focus-group', 'cookie-consent-link', 'qbsearch-input', 'template', 'action-menu', 'span', 'h3', 'td', 'p', 'code', 'thead', 'strong', 'li', 'ghcc-consent', 'script', 'summary', 'details-dialog', 'pre', 'svg', 'div', 'html', 'anchored-position', 'meta', 'body', 'title', 'turbo-frame', 'h2', 'modal-dialog', 'dialog-helper', 'form', 'th', 'custom-scopes', 'nav', 'img', 'action-list', 'style', 'button', 'main', 'details', 'a', 'scrollable-region', 'auto-check', 'h1', 'article', 'include-fragment', 'link', 'header', 'label', 'textarea', 'br', 'footer', 'input', 'table', 'em', 'head', 'tbody', 'ul', 'clipboard-copy', 'tool-tip', 'dialog', 'tr', 'react-partial'}

# %%
FinalTags['path']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 FinalTags['path']
#
# TypeError: 'set' object is not subscriptable
